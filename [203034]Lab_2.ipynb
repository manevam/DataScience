# %% [markdown]
# <ul><font size = 5 color='Orange'>
# Learning Goals</font>
# <font color = 'Orange'><li>Obtaining the Dataset</li>
# <li>Handling missing values</li>
# <li>Encoding the categorical data</li>
# <li>EDA</li>
# <li>Visualizations</li>
# </ul>

# %% [markdown]
# The Dataset for this exercise depends on your index number i.e number_of_data_set = index % 10:
#
#
# 0.  https://www.kaggle.com/ruchi798/drug-overdose-deaths
# 1.  https://www.kaggle.com/rishidamarla/employee-data-from-the-city-of-chicago
# 2.  https://www.kaggle.com/vikasukani/loan-eligible-dataset
# 3.  https://www.kaggle.com/tamilsel/healthcare-providers-data
# 4.  https://www.kaggle.com/chirag9073/europe-economic-crisis
# 5.  https://www.kaggle.com/bryanb/cac40-stocks-dataset
# 6.  https://www.kaggle.com/christofel04/cardiovascular-study-dataset-predict-heart-disea
# 7.  https://www.kaggle.com/tsaustin/us-historical-stock-prices-with-earnings-data
# 8.  https://www.kaggle.com/kimjihoo/coronavirusdataset (Dataset: PatientInfo.csv)
# 9.  https://www.kaggle.com/mczielinski/bitcoin-historical-data

# %% [markdown]
# # <font color = 'Orange'> Read your Dataset (.csv)</font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df_europe = pd.read_csv('/content/drive/MyDrive/Факултет/DataScience/Lab2/Europe_crisis.csv')

# %%
df_europe.head(10)
# Out:
#    Unnamed: 0  CC3  Country    Year  Banking Crisis   Systemic Crisis  \
# 0           0  AUT  Austria  1800.0              0.0              0.0
# 1           1  AUT  Austria  1801.0              0.0              0.0
# 2           2  AUT  Austria  1802.0              0.0              0.0
# 3           3  AUT  Austria  1803.0              0.0              0.0
# 4           4  AUT  Austria  1804.0              0.0              0.0
# 5           5  AUT  Austria  1805.0              0.0              0.0
# 6           6  AUT  Austria  1806.0              0.0              0.0
# 7           7  AUT  Austria  1807.0              0.0              0.0
# 8           8  AUT  Austria  1808.0              0.0              0.0
# 9           9  AUT  Austria  1809.0              0.0              0.0
#
#   exch_usd                                  National Currency  \
# 0      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 1      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 2      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 3      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 4      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 5      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 6      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 7      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 8      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 9      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
#
#                                         exch_sources  Domestic Debt  \
# 0  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 1  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 2  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 3  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 4  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 5  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 6  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 7  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 8  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 9  Primary source isGFD-RR_IFS official eop; alt1...            0.0
#
#   Sovereign External debt1  Sovereign External debt2  GDP_Weighted_default  \
# 0                        0                       0.0                  0.00
# 1                        0                       0.0                  0.00
# 2                        1                       1.0                  0.86
# 3                        1                       1.0                  0.86
# 4                        1                       1.0                  0.86
# 5                        1                       1.0                  0.86
# 6                        1                       1.0                  0.86
# 7                        1                       1.0                  0.86
# 8                        1                       1.0                  0.86
# 9                        1                       1.0                  0.86
#
#             Inflation  Independence  Currency Crises  Inflation Crises
# 0   14.64646464646464             1                1               0.0
# 1   29.24081323858143             1                1               1.0
# 2  11.554948079807115             1                0               0.0
# 3  12.448675361157424             1                0               0.0
# 4  -3.399989463738562             1                1               0.0
# 5  26.509580683860634             1                0               1.0
# 6  -2.933196739278615             1                0               0.0
# 7  -24.74227078930879             1                1               0.0
# 8  12.729910867700406             1                1               0.0
# 9   50.82640035784859             1                1               1.0

# %%
df_europe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4557 entries, 0 to 4556
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                4557 non-null   int64
#  1   CC3                       4557 non-null   object
#  2   Country                   4557 non-null   object
#  3   Year                      4557 non-null   float64
#  4   Banking Crisis            4081 non-null   float64
#  5   Systemic Crisis           4545 non-null   float64
#  6   exch_usd                  3732 non-null   object
#  7   National Currency         4122 non-null   object
#  8   exch_sources              4556 non-null   object
#  9   Domestic Debt             3896 non-null   float64
#  10  Sovereign External debt1  3905 non-null   object
#  11  Sovereign External debt2  3905 non-null   float64
#  12  GDP_Weighted_default      3903 non-null   float64
#  13  Inflation                 3647 non-null   object
#  14  Independence              4557 non-null   int64
#  15  Currency Crises           4557 non-null   int64
#  16  Inflation Crises          4195 non-null   float64
# dtypes: float64(7), int64(3), object(7)
# memory usage: 605.4+ KB

# %% [markdown]
# # <font color = 'Orange'> Target column/columns </font>
#
# Write some info about the target value/values

# %% [markdown]
# The target column shows number of Systemic crisis in the span of 1801-2016 in 21 European countries.

# %% [markdown]
# Visualize the target column

# %%
df_europe['Systemic Crisis'].value_counts()
# Out:
# 0.0    4320
# 1.0     225
# Name: Systemic Crisis, dtype: int64

# %%
import matplotlib.pyplot as plt
df_europe['Systemic Crisis'].hist()
plt.xticks(rotation=90)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2]),
#  <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# # <font color = 'Orange'>Detect the Missing values</font>

# %% [markdown]
# Count the percentage of missing values in every column of the Dataset.

# %%
missing_values = df_europe.isnull().sum()

# %%
missing_values_percent = (missing_values / len(df_europe)) * 100
missing_values_percent
# Out:
# Unnamed: 0                   0.000000
# CC3                          0.000000
# Country                      0.000000
# Year                         0.000000
# Banking Crisis              10.445469
# Systemic Crisis              0.263331
# exch_usd                    18.104016
# National Currency            9.545754
# exch_sources                 0.021944
# Domestic Debt               14.505157
# Sovereign External debt1    14.307659
# Sovereign External debt2    14.307659
# GDP_Weighted_default        14.351547
# Inflation                   19.969278
# Independence                 0.000000
# Currency Crises              0.000000
# Inflation Crises             7.943823
# dtype: float64

# %% [markdown]
# Visualize the missing values using Missingno library

# %%
import missingno as msno
msno.bar(df_europe)

# %% [markdown]
# ## <font color = 'Orange'> Find reasons for the missing values</font>
#
#
# With the help of visualization matrix, heatmap, dendrogram, show the dependence between the columns with missing values

# %%
msno.matrix(df_europe)

# %%
msno.heatmap(df_europe)

# %%
msno.dendrogram(df_europe)

# %% [markdown]
# Write the reasons for the missing values

# %% [markdown]
# Regarding the collumns Sovereign External debt1 and Sovereign External debt2: there are missing values beacuse only a portion of the 21 European countries had a monarchy and they didn't have a monarcy until 2016 rather some year in the past.
#
# Also on the matrix of missing values we can see that there are years for a certain country where info for Domestic Debt, Sovereign External debt1, Sovereign External debt2 and GDP_Weighted_default wasn't collected.
#
# From the heat map we can see that:
# 1. Banking Crisis and Inflation Crises are correlated
# 2. Sovereign External debt1 and GDP_Weighted_default are correlated
# 3. Sovereign External debt1 and Sovereign External debt2 are correlated
# 4. Sovereign External debt2 and GDP_Weighted_default are correlated

# %% [markdown]
# ## <font color = 'Orange'>Handle the missing values</font>

# %% [markdown]
# After you observed the data, the main goal is to know how the columns depend one to another. Therefore, the next step is to select one of the techniques of Machine Learning: Linear Regression, KNN Classification or Logistic Regression that you will use for handling the missing values. You don't need to use the whole dataset for detecting the missing values in one column, you can use a subset of columns that are making the prediction of the target missing value.

# %%
train = df_europe.head(5)

train
# Out:
#    Unnamed: 0  CC3  Country    Year  Banking Crisis   Systemic Crisis  \
# 0           0  AUT  Austria  1800.0              0.0              0.0
# 1           1  AUT  Austria  1801.0              0.0              0.0
# 2           2  AUT  Austria  1802.0              0.0              0.0
# 3           3  AUT  Austria  1803.0              0.0              0.0
# 4           4  AUT  Austria  1804.0              0.0              0.0
#
#   exch_usd                                  National Currency  \
# 0      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 1      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 2      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 3      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
# 4      NaN  1748-1892-Gulden, 1892-1923-Krone,1923-1998 sc...
#
#                                         exch_sources  Domestic Debt  \
# 0  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 1  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 2  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 3  Primary source isGFD-RR_IFS official eop; alt1...            0.0
# 4  Primary source isGFD-RR_IFS official eop; alt1...            0.0
#
#   Sovereign External debt1  Sovereign External debt2  GDP_Weighted_default  \
# 0                        0                       0.0                  0.00
# 1                        0                       0.0                  0.00
# 2                        1                       1.0                  0.86
# 3                        1                       1.0                  0.86
# 4                        1                       1.0                  0.86
#
#             Inflation  Independence  Currency Crises  Inflation Crises
# 0   14.64646464646464             1                1               0.0
# 1   29.24081323858143             1                1               1.0
# 2  11.554948079807115             1                0               0.0
# 3  12.448675361157424             1                0               0.0
# 4  -3.399989463738562             1                1               0.0

# %%
missing = df_europe.isnull()['Independence'].reset_index()

missing
# Out:
#       index  Independence
# 0         0         False
# 1         1         False
# 2         2         False
# 3         3         False
# 4         4         False
# ...     ...           ...
# 4552   4552         False
# 4553   4553         False
# 4554   4554         False
# 4555   4555         False
# 4556   4556         False
#
# [4557 rows x 2 columns]

# %% [markdown]
# # <font color = 'Orange'> Encode non numerical values </font>
#
# If this is still not passed on the classes just erase these columns

# %%
#add your code

# %% [markdown]
# # <font color = 'Orange'>Save the new Dataset(.csv) </font>

# %%
#add your code

# %% [markdown]
# Print the first rows of your final Dataset

# %%
#add your code

# %% [markdown]
# #<font color='orange'>EDA</font>

# %% [markdown]
# ## <font color='Orange'>Find statistic elements for the continuous variables</font>
# Like mean, median,  standard deviation, minimum, maximum, quantile,geometric mean

# %%
#add your code

# %% [markdown]
# ## <font color = 'Orange'>Find the frequencies for the categorical variables </font>

# %%
#add your code

# %% [markdown]
# # <font color = 'Orange'>Data visualization </font>

# %% [markdown]
# ## <font color = 'Orange'>Find the distribution of given attributes</font>

# %% [markdown]
# Which of the attributes(columns) did you choose?

# %% [markdown]
# add your answer here

# %% [markdown]
# **Make the visualizations using histograms, bar charts, etc.**

# %%
#add your code

# %% [markdown]
# Add as many codeboxes as you need

# %% [markdown]
# ## <font color = 'Orange'>Visualize the relationship between the attributes</font>

# %%
#add your code

# %% [markdown]
# ## <font color = 'Orange'>Make comparison of the columns</font>

# %% [markdown]
# Using multiple histograms, box-plots, scatter plots, pairplots, etc.

# %%
#add your code

# %% [markdown]
# # <font color = 'Orange'>EXTRA: Complex visualizations</font>
# For this you will need a basic knowladge of the Plotly library: https://plotly.com/graphing-libraries/
# and for deploying the visualization as a web app you will need the Dash library for that take a look of: https://github.com/plotly/dash
